# %%
import requests
import pandas as pd

# %%
# !pip install requests pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\PC\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
API_KEY = "56a2d97b89a2410b8554c68864fc5152"

url = f"https://newsapi.org/v2/everything?q=war OR economy OR crisis OR inflation&language=en&apiKey={API_KEY}"

response = requests.get(url)
data = response.json()

print(data.keys())
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
articles = data['articles']

news_list = []

for article in articles:
    news_list.append({
        "title": article["title"],
        "description": article["description"],
        "source": article["source"]["name"],
        "published_at": article["publishedAt"]
    })

df = pd.DataFrame(news_list)

df.head()
# Out:
#                                                title  \
# 0  Higher Oil Prices From Trump’s Iran War Risk K...
# 1  Paramount’s Takeover of Warner Bros Is Turning...
# 2  The Iran war is driving an oil shock — but not...
# 3  Oil surges to its highest price since 2023, an...
# 4  Trump Advisor Says Pain for U.S. Consumers ‘La...
#
#                                          description            source  \
# 0  President Deals seems to be setting the global...       Gizmodo.com
# 1  Going to war with Iran has suddenly brought Ch...       Gizmodo.com
# 2  Oil shock from Iran war raises inflation conce...  Business Insider
# 3  Stocks fell Friday on worries that the economy...               NPR
# 4  Kevin Hassett claims the war will last 4-6 weeks.       Gizmodo.com
#
#            published_at
# 0  2026-03-19T19:30:17Z
# 1  2026-03-09T18:05:37Z
# 2  2026-03-16T06:47:18Z
# 3  2026-03-06T20:17:20Z
# 4  2026-03-17T18:40:09Z

# %%
df.to_csv("data/global_news.csv", index=False)
print("File saved successfully")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.to_csv("data/global_news.csv", index=False)
#       2 print("File saved successfully")
#
# File ~\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
# ...

# %%
import os

os.makedirs("data", exist_ok=True)
print("data folder ensured")
# Out:
# data folder ensured

# %%
df.to_csv("data/global_news.csv", index=False)
print("File saved successfully")
# Out:
# File saved successfully

# %%
# Remove rows with missing values
df = df.dropna()

# Reset index
df = df.reset_index(drop=True)

# Convert text to lowercase
df["title"] = df["title"].str.lower()
df["description"] = df["description"].str.lower()

df.head()
# Out:
#                                                title  \
# 0  higher oil prices from trump’s iran war risk k...
# 1  paramount’s takeover of warner bros is turning...
# 2  the iran war is driving an oil shock — but not...
# 3  oil surges to its highest price since 2023, an...
# 4  trump advisor says pain for u.s. consumers ‘la...
#
#                                          description            source  \
# 0  president deals seems to be setting the global...       Gizmodo.com
# 1  going to war with iran has suddenly brought ch...       Gizmodo.com
# 2  oil shock from iran war raises inflation conce...  Business Insider
# 3  stocks fell friday on worries that the economy...               NPR
# 4  kevin hassett claims the war will last 4-6 weeks.       Gizmodo.com
#
#            published_at
# 0  2026-03-19T19:30:17Z
# 1  2026-03-09T18:05:37Z
# 2  2026-03-16T06:47:18Z
# 3  2026-03-06T20:17:20Z
# 4  2026-03-17T18:40:09Z

# %%
# !pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import nltk
#       2 nltk.download('punkt')
#       3 nltk.download('stopwords')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.5 kB 108.9 kB/s eta 0:00:01
#      ------------------ ------------------- 20.5/41.5 kB 108.9 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 153.9 kB/s eta 0:00:00
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# ...
#    ---------------------------------------- 0.0/278.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/278.0 kB ? eta -:--:--
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def extract_keywords(text):
    words = word_tokenize(text)
    keywords = [word for word in words if word.isalnum() and word not in stop_words]
    return keywords

df["keywords"] = df["description"].apply(extract_keywords)

df[["description", "keywords"]].head()
# Out:
#                                          description  \
# 0  president deals seems to be setting the global...
# 1  going to war with iran has suddenly brought ch...
# 2  oil shock from iran war raises inflation conce...
# 3  stocks fell friday on worries that the economy...
# 4  kevin hassett claims the war will last 4-6 weeks.
#
#                                             keywords
# 0  [president, deals, seems, setting, global, eco...
# 1  [going, war, iran, suddenly, brought, china, b...
# 2  [oil, shock, iran, war, raises, inflation, con...
# 3  [stocks, fell, friday, worries, economy, could...
# 4         [kevin, hassett, claims, war, last, weeks]

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
def classify_crisis(keywords):
    keywords_set = set(keywords)

    war_words = {"war", "military", "conflict", "attack", "missile", "troops", "defense"}
    economy_words = {"economy", "inflation", "recession", "market", "stocks", "trade", "oil", "prices"}
    climate_words = {"climate", "flood", "heatwave", "earthquake", "storm", "wildfire", "drought"}

    if keywords_set & war_words:
        return "war"
    elif keywords_set & economy_words:
        return "economy"
    elif keywords_set & climate_words:
        return "climate"
    else:
        return "other"

df["crisis_category"] = df["keywords"].apply(classify_crisis)

df[["title", "keywords", "crisis_category"]].head()
# Out:
#                                                title  \
# 0  higher oil prices from trump’s iran war risk k...
# 1  paramount’s takeover of warner bros is turning...
# 2  the iran war is driving an oil shock — but not...
# 3  oil surges to its highest price since 2023, an...
# 4  trump advisor says pain for u.s. consumers ‘la...
#
#                                             keywords crisis_category
# 0  [president, deals, seems, setting, global, eco...         economy
# 1  [going, war, iran, suddenly, brought, china, b...             war
# 2  [oil, shock, iran, war, raises, inflation, con...             war
# 3  [stocks, fell, friday, worries, economy, could...             war
# 4         [kevin, hassett, claims, war, last, weeks]             war

# %%
df["crisis_category"].value_counts()
# Out:
# crisis_category
# war        49
# other      25
# economy    17
# Name: count, dtype: int64

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.3 MB 5.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.3 MB 6.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.3 MB 5.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.3 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.3 MB 5.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.3 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 3.9 MB/s  0:00:02
# ...

# %%
import matplotlib.pyplot as plt

# Count categories
counts = df["crisis_category"].value_counts()

# Plot
counts.plot(kind='bar')

plt.title("Global Crisis Distribution")
plt.xlabel("Crisis Type")
plt.ylabel("Number of News Articles")

plt.show()

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 4.0 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\PC\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
from textblob import download_corpora
download_corpora.download_all()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from textblob import download_corpora
#       2 download_corpora.download_all()
#
# ModuleNotFoundError: No module named 'textblob'

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

df["sentiment_score"] = df["description"].apply(get_sentiment)

df[["description", "sentiment_score"]].head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from textblob import TextBlob
#       3 def get_sentiment(text):
#       4     analysis = TextBlob(text)
#
# ModuleNotFoundError: No module named 'textblob'

# %%
def sentiment_label(score):
    if score > 0:
        return "positive"
    elif score < 0:
        return "negative"
    else:
        return "neutral"

df["sentiment"] = df["sentiment_score"].apply(sentiment_label)

df[["description", "sentiment_score", "sentiment"]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiment_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 9
#       6     else:
# ...

# %%
import sys
# !{sys.executable} -m pip install textblob
# Out:
# ...
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\PC\AppData\Local\Python\pythoncore-3.11-64\python.exe -m pip install --upgrade pip

# %%
from textblob import download_corpora
download_corpora.download_all()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

df["sentiment_score"] = df["description"].apply(get_sentiment)

# %%
def sentiment_label(score):
    if score > 0:
        return "positive"
    elif score < 0:
        return "negative"
    else:
        return "neutral"

df["sentiment"] = df["sentiment_score"].apply(sentiment_label)

df[["description", "sentiment_score", "sentiment"]].head()
# Out:
#                                          description  sentiment_score  \
# 0  president deals seems to be setting the global...         0.000000
# 1  going to war with iran has suddenly brought ch...         0.000000
# 2  oil shock from iran war raises inflation conce...        -0.033333
# 3  stocks fell friday on worries that the economy...         0.160000
# 4  kevin hassett claims the war will last 4-6 weeks.         0.000000
#
#   sentiment
# 0   neutral
# 1   neutral
# 2  negative
# 3  positive
# 4   neutral

# %%
def crisis_score(row):
    score = 0
    
    # Sentiment impact (negative = high crisis)
    score += abs(row["sentiment_score"]) * 50
    
    # Category weight
    if row["crisis_category"] == "war":
        score += 50
    elif row["crisis_category"] == "economy":
        score += 30
    elif row["crisis_category"] == "climate":
        score += 20
    else:
        score += 10
    
    return round(score, 2)

df["crisis_severity_score"] = df.apply(crisis_score, axis=1)

df[["title", "crisis_category", "sentiment", "crisis_severity_score"]].head()
# Out:
#                                                title crisis_category  \
# 0  higher oil prices from trump’s iran war risk k...         economy
# 1  paramount’s takeover of warner bros is turning...             war
# 2  the iran war is driving an oil shock — but not...             war
# 3  oil surges to its highest price since 2023, an...             war
# 4  trump advisor says pain for u.s. consumers ‘la...             war
#
#   sentiment  crisis_severity_score
# 0   neutral                  30.00
# 1   neutral                  50.00
# 2  negative                  51.67
# 3  positive                  58.00
# 4   neutral                  50.00

# %%
df.to_csv("data/global_crisis_final.csv", index=False)
print("Final dataset saved successfully")
# Out:
# Final dataset saved successfully
